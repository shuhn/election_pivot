# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from math import sqrt
from matplotlib.font_manager import FontProperties

from matplotlib.patches import Circle, Wedge, Polygon
from matplotlib.collections import PatchCollection


# %matplotlib inline

# %%
dem_dates = ('skip',  'skip',   'Oct.', 'Nov.', 'Dec.', 'Jan.', 'Feb.', 'Feb.', 'AVERAGE',   'Mar.', 'Mar.', 'Apr.', 'Sep.', 'Oct.')
rep_dates = ('Aug', 'Sep.', 'Oct.', 'Nov.', 'Dec.', 'Jan.', 'Feb.', 'Feb.', 'Feb.', 'Mar.', 'Mar.', 'AVERAGE',  'Sep.', 'Oct.')
MASTER_DATES = ('Aug', 'Sep.', 'Oct.', 'Nov.', 'Dec.', 'Jan.', 'Feb.', 'Feb.', 'Feb.', 'Mar.', 'Mar.', 'Apr.', 'Sep.', 'Oct.')

# %% [markdown]
# ### Q1

# %%
trump_f = [0.15, 0.15, 0.03, 0.05, 0.11, 0.15, 0.06, 0.18, 0.24, 0.29, 0.13, 0.09, .11]
t_avg = sum(trump_f) / len(trump_f)
clinton_f = [0.11, 0.0, 0.06, -0.05, -0.03, -0.04, -0.01, -0.03, -.02, -.09, -.11]
c_avg = sum(clinton_f) / len(clinton_f)

# %%
#ADJUSTED
clinton_f_adj = [c_avg, c_avg, 0.11, 0.0, 0.06, -0.05, -0.03, -0.04, c_avg, -0.01, -0.03, -.02, -.09, -.11]
trump_f_adj = [0.15, 0.15, 0.03, 0.05, 0.11, 0.15, 0.06, 0.18, 0.24, 0.29, 0.13, t_avg, 0.09, .11]
print len(clinton_f_adj), len(trump_f_adj)
# Out:
# 14 14

# %%
plt.style.use('fivethirtyeight')
fig, ax1 = plt.subplots(figsize=(9, 7))
ax1.plot(clinton_f_adj, color='blue', lw=2)

ax1.set_ylim([-.15, .4])
ax1.axvline(11, color='black', alpha=0.7, linestyle = "-", lw=2)
ax1.axhline(0, color='black', alpha=0.7, linestyle = "-", lw=2)
ax1.axhline(c_avg, color='blue', alpha=0.9, linestyle = "--", lw=2)

ax1.text(.42, .77,'Primaries', ha='center', va='center', transform=ax1.transAxes, fontsize=14)
ax1.text(.92, .79,'General', ha='center', va='center', transform=ax1.transAxes, fontsize=14)
ax1.text(.92, .75,'Election', ha='center', va='center', transform=ax1.transAxes, fontsize=14)

ax1.axvline(11, color='black', alpha=0.7, linestyle = "-", lw=2, label = 'Assertiveness by Debate')
ax1.axvline(11, color='black', alpha=0.7, linestyle = "--", lw=.01, label = 'Mean Assertiveness')

ax1.locator_params(nbins=14)
ax1.set_xticklabels(MASTER_DATES)
ax1.set_ylabel('Assertiveness')
plt.tick_params(axis='both', which='major', labelsize=13)
plt.tick_params(axis='both', which='minor', labelsize=13)
leg = plt.legend(loc = 'upper left', prop={'size':14})

for legobj in leg.legendHandles:
    legobj.set_linewidth(2.0)

plt.savefig('clinton_q1.eps', format='eps', dpi=2000)

# %%
plt.style.use('fivethirtyeight')

fig, ax1 = plt.subplots(figsize=(9, 7))

ax1.plot(trump_f_adj, color='red', lw=2)
ax1.plot(clinton_f_adj, color='blue', lw=2)

ax1.set_ylim([-.15, .4])
ax1.axvline(11, color='black', alpha=0.7, linestyle = "-", lw=2)
ax1.axhline(0, color='black', alpha=0.7, linestyle = "-", lw=2)

ax1.axhline(t_avg, color='red', alpha=0.9, linestyle = "--", lw=2)
ax1.axhline(c_avg, color='blue', alpha=0.9, linestyle = "--", lw=2)

ax1.axvline(11, color='black', alpha=0.7, linestyle = "-", lw=2, label = 'Assertiveness by Debate')
ax1.axvline(11, color='black', alpha=0.7, linestyle = "--", lw=.01, label = 'Mean Assertiveness')

ax1.text(.42, .77,'Primaries', ha='center', va='center', transform=ax1.transAxes, fontsize=14)
ax1.text(.92, .79,'General', ha='center', va='center', transform=ax1.transAxes, fontsize=14)
ax1.text(.92, .75,'Election', ha='center', va='center', transform=ax1.transAxes, fontsize=14)

ax1.locator_params(nbins=14)
ax1.set_xticklabels(MASTER_DATES)
ax1.set_ylabel('Assertiveness')
plt.tick_params(axis='both', which='major', labelsize=13)
plt.tick_params(axis='both', which='minor', labelsize=13)
leg = plt.legend(loc = 'upper left', prop={'size':14})

for legobj in leg.legendHandles:
    legobj.set_linewidth(2.0)

plt.savefig('both_q1.eps', format='eps', dpi=2000)

# %% [markdown]
# ### Q2

# %%
clinton_s = [0.46059628777, 0.473386814837, 0.480774694166, 0.474977908127, 0.440111390254, 0.482383309171, 0.455660664221, 0.479662342358, 0.490279415132, 0.47652154346835224, 0.4895848559809599]
# clinton_p = [0.14994547155, 0.114680636014, 0.154516311125, 0.131869820344, 0.162828622223, 0.149138902063, 0.16696063665, 0.181325683235, 0.175456572179, 0.16826592615422417, 0.15472820505612708]
clinton_nltk = [0.510442829001, 0.489079012186]

# %%
c_avg_s = sum(clinton_s) / len(clinton_s)

# %%
trump_s = [0.502557720058, 0.510390216961, 0.520650906522, 0.522131608686, 0.524993261456, 0.525073009733, 0.501029188989,  0.491280828439, 0.515618648135, 0.492371497168, 0.533245212465, 0.5252667898750849, 0.5270328008493402]
# trump_p = [0.183231128695, 0.148512649674, 0.126104276498, 0.0955778981728, 0.181508310872, 0.123271913666, 0.198576819094, 0.108995557232, 0.15722933546, 0.127605606385, 0.129412858417,0.12346835661351802,0.1077794717956315]
trump_nltk = [0.428836133066, 0.411885644154]

# %%
t_avg_s = sum(trump_s) / len(trump_s)

# %%
#ADJUSTED SUBJECTIVITY
clinton_s_adj = [c_avg_s, c_avg_s, 0.46059628777, 0.473386814837, 0.480774694166, 0.474977908127, 0.440111390254, 0.482383309171, c_avg_s ,0.455660664221, 0.479662342358, 0.490279415132, 0.47652154346835224, 0.4895848559809599]
trump_s_adj = [0.502557720058, 0.510390216961, 0.520650906522, 0.522131608686, 0.524993261456, 0.525073009733, 0.501029188989,  0.491280828439, 0.515618648135, 0.492371497168, 0.533245212465, t_avg_s, 0.5252667898750849, 0.5270328008493402]

# %%
fig, ax1 = plt.subplots(figsize=(9, 7))

plt.style.use('fivethirtyeight')

ax1.plot(clinton_s_adj, color='blue', lw=2)

ax1.set_ylim([.4,.6])
ax1.axvline(11, color='black', alpha=0.7, linestyle = "-", lw=2, label = 'Subjectivity')
ax1.axvline(11, color='black', alpha=0.7, linestyle = "--", lw=.01, label = 'Positivity')

ax1.axhline(clinton_nltk[0], color='blue', alpha=0.9, linestyle = "--", xmax = 12.0/14-.01, lw=2)
ax1.axhline(clinton_nltk[1], color='blue', alpha=0.9, linestyle = "--", xmin = 12.0/14, lw=2)

ax1.text(.42, .80,'Primaries', ha='center', va='center', transform=ax1.transAxes, fontsize=14)
ax1.text(.92, .82,'General', ha='center', va='center', transform=ax1.transAxes, fontsize=14)
ax1.text(.92, .78,'Election', ha='center', va='center', transform=ax1.transAxes, fontsize=14)

ax1.locator_params(nbins=14)
ax1.set_xticklabels(MASTER_DATES)
plt.tick_params(axis='both', which='major', labelsize=13)
plt.tick_params(axis='both', which='minor', labelsize=13)
leg = plt.legend(loc = 'upper left', prop={'size':14})

for legobj in leg.legendHandles:
    legobj.set_linewidth(2.0)
    
plt.savefig('graphs/clinton_q2.eps', format='eps', dpi=2000)

# %%
fig, ax1 = plt.subplots(figsize=(9, 7))

plt.style.use('fivethirtyeight')

ax1.plot(trump_s_adj, color='red', lw=2)
ax1.plot(clinton_s_adj, color='blue', lw=2)

ax1.set_ylim([.4,.6])
ax1.axvline(11, color='black', alpha=0.7, linestyle = "-", lw=2, label = 'Subjectivity')
ax1.axvline(11, color='black', alpha=0.7, linestyle = "--", lw=.01, label = 'Positivity')

ax1.axhline(trump_nltk[0], color='red', alpha=0.9, linestyle = "--", xmax = 12.0/14-.01, lw=2)
ax1.axhline(trump_nltk[1], color='red', alpha=0.9, linestyle = "--", xmin = 12.0/14, lw=2)

ax1.axhline(clinton_nltk[0], color='blue', alpha=0.9, linestyle = "--", xmax = 12.0/14-.01, lw=2)
ax1.axhline(clinton_nltk[1], color='blue', alpha=0.9, linestyle = "--", xmin = 12.0/14, lw=2)

ax1.text(.42, .80,'Primaries', ha='center', va='center', transform=ax1.transAxes, fontsize=14)
ax1.text(.92, .82,'General', ha='center', va='center', transform=ax1.transAxes, fontsize=14)
ax1.text(.92, .78,'Election', ha='center', va='center', transform=ax1.transAxes, fontsize=14)

ax1.locator_params(nbins=14)
ax1.set_xticklabels(MASTER_DATES)
plt.tick_params(axis='both', which='major', labelsize=13)
plt.tick_params(axis='both', which='minor', labelsize=13)
leg = plt.legend(loc = 'upper left', prop={'size':14})

for legobj in leg.legendHandles:
    legobj.set_linewidth(2.0)
    
plt.savefig('graphs/both_q2.eps', format='eps', dpi=2000)

# %% [markdown]
# Show Clinton's graphs first, then plot Trump on top. Explain with reference to Clinton what's happening, and then drop in Trump and note main differences.

# %% [markdown]
# ### Q4

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(13.5, 10.5))

"""
PRIMARIES:: 4 TOPICS, ngram_range=(1,3)
1) Make America Great Again : 125
2) Immigration : 117 
3) Foreign Policy : 58 
4) Hillary's Record : 18 
"""
total = 125 + 117 + 58 + 18 
x1 = 125.0 / total 
x2 = 117.0 / total 
x3 = 58.0 / total 
x4 = 18.0 / total

x1_s = sqrt(x1*5)
x2_s = sqrt(x2*5)
x3_s = sqrt(x3*5)
x4_s = sqrt(x4*5)

patches = []
circles = [(-1.2, .7, x1_s), (1.55, .7, x2_s), (.2, -1.15, x3_s), (-1.25, -1.25, x4_s)]
for x1, y1, r in circles:
    circle = Circle((x1, y1), r, edgecolor='black')
    patches.append(circle)
ax.set_ylim([-3,3])
ax.set_xlim([-3,3])

colors = np.array([125, 117, 58, 18])

p = PatchCollection(patches, cmap=matplotlib.cm.Reds, alpha=.9)
p.set_array(np.array(colors))
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.add_collection(p)
plt.colorbar(p)

ax.text(.29, .62,'Make America Great Again', ha='center', va='center', transform=ax.transAxes, fontsize=16, backgroundcolor='white', color = 'black')
ax.text(.75, .62,'Immigration', ha='center', va='center', transform=ax.transAxes, fontsize=16,backgroundcolor='white', color = 'black')
ax.text(.29, .3,'Foreign Policy', ha='center', va='center', transform=ax.transAxes, fontsize=16, color = 'black')
ax.text(.53, .3,'Clinton\'s Record', ha='center', va='center', transform=ax.transAxes, fontsize=16, color = 'black')

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(13.5, 10.5))

"""
GE:: 4 TOPICS, ngram_range=(1,2)
1) Make America Great Again : 63
2) Taxes & Regulation : 14
3) Foreign Policy : 11
4) Law Enforcement : 10 
"""
total = 63 + 14 + 11 + 10 
x1 = 63.0 / total
x2 = 14.0 / total 
x3 = 11.0 / total 
x4 = 10.0 / total

x1_s = sqrt(x1*5)
x2_s = sqrt(x2*5)
x3_s = sqrt(x3*5)
x4_s = sqrt(x4*5)

patches = []
circles = [(-.7, .7, x1_s), (1.96, .7, x2_s), (1.25, -.95, x3_s), (-.65, -1.8, x4_s)]
for x1, y1, r in circles:
    circle = Circle((x1, y1), r, edgecolor='black')
    patches.append(circle)
ax.set_ylim([-3,3])
ax.set_xlim([-3,3])

colors = np.array([63, 14, 11, 10])

p = PatchCollection(patches, cmap=matplotlib.cm.Reds, alpha=.9)
p.set_array(np.array(colors))
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.add_collection(p)
# ax.set_title('Hi')
plt.colorbar(p)

ax.text(.33, .76, 'Make America Great Again', ha='center', va='center', transform=ax1.transAxes, fontsize=16, backgroundcolor='white', color = 'black')
ax.text(.82, .76,'Taxes & Regulation', ha='center', va='center', transform=ax1.transAxes, fontsize=16, color = 'black')
ax.text(.69, .39,'Foreign Policy', ha='center', va='center', transform=ax1.transAxes, fontsize=16, color = 'black')
ax.text(.34, .2,'Law Enforcement', ha='center', va='center', transform=ax1.transAxes, fontsize=16, color = 'black')

plt.savefig('graphs/trump_g_q4.eps', format='eps')

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(13.5, 10.5))

"""
PRIMARIES:: 8 TOPICS, ngram_range=(1,3)
1) Foreign Policy : 64
2) Financial Regulation : 62
3) Jobs / Opportunity : 60 
4) Immigration : 52
5) Education : 44
6) Gun Control : 30
7) Health Care : 29
8) Law Enforcement : 29
"""

total = 64+62+60+52+44+30+29+29
x1 = 64.0 / total 
x2 = 62.0 / total 
x3 = 60.0 / total 
x4 = 52.0 / total
x5 = 44.0 / total
x6 = 30.0 / total 
x7 = 29.0 / total 
x8 = 29.0 / total

x1_s = sqrt(x1*5)
x2_s = sqrt(x2*5)
x3_s = sqrt(x3*5)
x4_s = sqrt(x4*5)
x5_s = sqrt(x5*5)
x6_s = sqrt(x6*5)
x7_s = sqrt(x7*5)
x8_s = sqrt(x8*5)

patches = []
circles = [(-1.8, 0, x1_s), (-1.8+x1_s*2, 0, x2_s), (-1.8+x1_s*2+x2_s*2, 0, x3_s),
           (-.85, -1.5, x4_s), (-.7+2*x4_s, -1.4, x5_s), (-1.2, 1.55, x6_s),
           (-1.2+2*x6_s, 1.55, x7_s), (-1.2+2*x6_s+2*x7_s, 1.55, x8_s)]
for x1, y1, r in circles:
    circle = Circle((x1, y1), r)
    patches.append(circle)
ax.set_ylim([-3,3])
ax.set_xlim([-3,3])

colors = np.array([64,62,60,52,44,30,29,29])

p = PatchCollection(patches, cmap=matplotlib.cm.Blues, alpha=.9)
p.set_array(np.array(colors))
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.add_collection(p)
plt.colorbar(p)

ax.text(.14, .6,'Foreign Policy', ha='center', va='center', transform=ax1.transAxes, fontsize=16, backgroundcolor='white', color = 'black')
ax.text(.47, .6,'Financial Regulation', ha='center', va='center', transform=ax1.transAxes, fontsize=16,backgroundcolor='white', color = 'black')
ax.text(.8, .6,'Jobs & Opportunity', ha='center', va='center', transform=ax1.transAxes, fontsize=16, color = 'black', backgroundcolor='white')
ax.text(.31, .27,'Immigration', ha='center', va='center', transform=ax1.transAxes, fontsize=16,backgroundcolor='white', color = 'black')
ax.text(.64, .29,'Education', ha='center', va='center', transform=ax1.transAxes, fontsize=16, backgroundcolor='white', color = 'black')
ax.text(.24, .95,'Gun Control', ha='center', va='center', transform=ax1.transAxes, fontsize=16, color = 'black')
ax.text(.475, .95,'Health Care', ha='center', va='center', transform=ax1.transAxes, fontsize=16, color = 'black')
ax.text(.7, .95,'Law Enforcement', ha='center', va='center', transform=ax1.transAxes, fontsize=16, color = 'black')

plt.savefig('graphs/clinton_p_q4.eps', format='eps', dpi=1000)

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(13.5, 10.5))

"""
GE:: 8 TOPICS, ngram_range=(1,1)
1) Donald's Record : 14
2) Financial Regulation : 13
3) Health Care : 12
4) Supreme Court : 11
5) Law Enforcement : 9 
6) Fact Checking : 7 
7) Foreign Policy : 5 
8) Jobs / Opportunity : 3
"""

total = 14+13+12+11+9+7+5+3
x1 = 14.0 / total 
x2 = 13.0 / total 
x3 = 12.0 / total 
x4 = 11.0 / total
x5 = 9.0 / total
x6 = 7.0 / total 
x7 = 5.0 / total 
x8 = 3.0 / total

x1_s = sqrt(x1*5)
x2_s = sqrt(x2*5)
x3_s = sqrt(x3*5)
x4_s = sqrt(x4*5)
x5_s = sqrt(x5*5)
x6_s = sqrt(x6*5)
x7_s = sqrt(x7*5)
x8_s = sqrt(x8*5)

patches = []
circles = [(-1.8, 0, x1_s), (-1.84+x1_s*2, 0, x2_s), (-1.9+x1_s*2+x2_s*2, 0, x3_s),
           (-.82, -1.5, x4_s), (-.7+2*x4_s, -1.4, x5_s), (-1.2, 1.55, x6_s),
           (-1.2+2*x6_s, 1.55, x7_s), (-1.2+2*x6_s+2*x7_s, 1.55, x8_s)]
for x1, y1, r in circles:
    circle = Circle((x1, y1), r)
    patches.append(circle)
ax.set_ylim([-3,3])
ax.set_xlim([-3,3])

colors = np.array([14,13,12,11,9,7,5,3])

p = PatchCollection(patches, cmap=matplotlib.cm.Blues, alpha=.9)
p.set_array(np.array(colors))
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.add_collection(p)
plt.colorbar(p)

ax.text(.14, .62,'Trump\'s Record', ha='center', va='center', transform=ax1.transAxes, fontsize=16, backgroundcolor='white', color = 'black')
ax.text(.47, .62,'Financial Regulation', ha='center', va='center', transform=ax1.transAxes, fontsize=16,backgroundcolor='white', color = 'black')
ax.text(.8, .62,'Health Care', ha='center', va='center', transform=ax1.transAxes, fontsize=16, color = 'black', backgroundcolor='white')
ax.text(.31, .29,'Supreme Court', ha='center', va='center', transform=ax1.transAxes, fontsize=16,backgroundcolor='white', color = 'black')
ax.text(.64, .31,'Law Enforcement', ha='center', va='center', transform=ax1.transAxes, fontsize=16, backgroundcolor='white', color = 'black')
ax.text(.24, .97,'Fact Checking', ha='center', va='center', transform=ax1.transAxes, fontsize=16, color = 'black')
ax.text(.475, .97,'Foreign Policy', ha='center', va='center', transform=ax1.transAxes, fontsize=16, color = 'black')
ax.text(.7, .97,'Jobs & Opportunity', ha='center', va='center', transform=ax1.transAxes, fontsize=16, color = 'black')

# %% [markdown]
# CLINTON
#
# PRIMARIES:: 8 TOPICS, ngram_range=(1,3)
# 1) Foreign Policy : 64
# 2) Financial Regulation : 62
# 3) Jobs / Opportunity : 60
# 4) Immigration : 52
# 5) Education : 44
# 6) Gun Control : 30
# 7) Health Care : 29
# 8) Law Enforcement : 29
#
#
# GE:: 8 TOPICS, ngram_range=(1,1)
# 1) Donald's Record : 14
# 2) Financial Regulation : 13
# 3) Health Care : 12
# 4) Supreme Court : 11
# 5) Law Enforcement : 9
# 6) Fact Checking : 7
# 7) Foreign Policy : 5
# 8) Jobs / Opportunity : 3
#
# TRUMP
#
# PRIMARIES:: 4 TOPICS, ngram_range=(1,3)
# 1) Make America Great Again : 125
# 2) Immigration : 117
# 3) Foreign Policy : 58
# 4) Hillary's Record : 18
#
#
# GE:: 4 TOPICS, ngram_range=(1,2)
# 1) Make America Great Again : 63
# 2) Taxes & Regulation : 14
# 3) Foreign Policy : 11
# 4) Law Enforcement : 10
